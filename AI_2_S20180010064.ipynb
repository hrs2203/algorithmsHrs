# %% [markdown]
# # Assignment 2
# ### Submitted By : Hrishabh Pandey, Section A, S20180010064

# %% [markdown]
# ## Intorduction
#
# Here in this assignment, I have tried to impliment Tic Tac Toe and Open field Tic Tac Toe ( option 1 and 3 ), to play simple Tic Tac Toe, please choose x=3, y=3, cutCount=3
#
# --------------------------
# ## How to Play
#
# Before start playing, Please Go through this README.md to get required info
# To start playing, run all cells using `Ctr+Shift+p -> Run All Cells`
#
# -------
# ### Play in Command Line Version
# use the function `playGame()` at the end to start the command line version. You will be asked for input, provide it in designated stop as asked by a prompt show in the figure below
# ![commandLineInput](./CommandLineInp.png)
#
# For an nXm block, input should be in range [1,n], [1,m] format input as `1 3` seprated by space
#
# User Move are marked with `X`, Computer Move are maked with `O`, empty boxes are marked with `.`
#
# If You Wish to use a particular algo or change board size from 3X3 to nXm and change cutCount to cut and want to search till a depth of drp use `playGame(AlgoName, n, m, cut, drp)`
#
# - Name of All used Algorithm ( enter one of them as needed in AlgoName )
#     - minmax_decision
#     - alpha_beta_search
#     - depth_limited_minmax_decision,
#     - depth_limited_alpha_beta_search
#     - custom_decision
#
# ------
# ### Play Visual Version By PyGame
# use the function `takePref()` to start the PyGame version you will be asked for input, provide it in designated stop as asked by a prompt show in the figure below
#
# ![visualInput](./visImp.png)
#
#
# Upon filling all boxex you will be promted as show below
#
# ![emptyBox](./emptyBox.png)
#
#
# Click the Block you want to make a move on. User moves are marked with GREEN, computer moves are marked with RED
#
# ![mov1](./UserMove1.png)
#
#
# While playing whose move is this will be shown on the title bar as in abouve images, if that is not visible, you can also see in the printed notebook output. Try Not to Loose
#
# ![mov2](./UserMove2.png)

# %% [markdown]
# ## General Inport Statements

# %%
import numpy as np
import sys, time, pygame
from collections import namedtuple
from pygame.locals import *

# %% [markdown]
# ## Game Model Defination

# %%
class Game:
    def actions(self, state):
        raise NotImplementedError

    def result(self, state, move):
        raise NotImplementedError

    def utility(self, state, player):
        raise NotImplementedError

    def terminal_test(self, state):
        return not self.actions(state)

    def to_move(self, state):
        return state.to_move

    def display(self, state):
        print(state)

    def __repr__(self):
        return '<{}>'.format(self.__class__.__name__)

    def play_game(self, *players):
        """Play an n-person, move-alternating game."""
        state = self.initial
        while True:
            for player in players:
                move = player(self, state)
                state = self.result(state, move)
                if self.terminal_test(state):
                    self.display(state)
                    return self.utility(state, self.to_move(self.initial))

# %% [markdown]
# ## Generalized Tic Tac Toe Defination

# %%
GameState = namedtuple('GameState', 'to_move, utility, board, moves, depth')

class TicTacToe(Game):
    """Play TicTacToe on an h x v board, with Max (first player) playing 'X'.
    A state has the player to move, a cached utility, a list of moves in
    the form of a list of (x, y) positions, and a board, in the form of
    a dict of {(x, y): Player} entries, where Player is 'X' or 'O'."""

    def __init__(self, h=3, v=3, k=3):
        self.h = h
        self.v = v
        self.k = k
        moves = [(x, y) for x in range(1, h + 1) for y in range(1, v + 1)]
        self.initial = GameState(to_move='X', utility=0, board={}, moves=moves, depth=0)

    def actions(self, state):
        """Legal moves are any square not yet taken."""
        return state.moves

    def result(self, state, move):
        if move not in state.moves:
            return state  # Illegal move has no effect
        board = state.board.copy()
        board[move] = state.to_move
        moves = list(state.moves)
        moves.remove(move)
        return GameState(to_move=('O' if state.to_move == 'X' else 'X'),
                         utility=self.compute_utility(board, move, state.to_move),
                         board=board, moves=moves, depth=state.depth+1)
    
    def custom_result(self, state, move):
        if move not in state.moves:
            return state  # Illegal move has no effect
        board = state.board.copy()
        board[move] = state.to_move
        moves = list(state.moves)
        moves.remove(move)
        return GameState(to_move=('O' if state.to_move == 'X' else 'X'),
                         utility=self.custom_compute_utility(board, move, state.to_move),
                         board=board, moves=moves, depth=state.depth+1)
    

    def utility(self, state, player):
        """Return the value to player; 1 for win, -1 for loss, 0 otherwise."""
        return state.utility if player == 'X' else -state.utility

    def terminal_test(self, state):
        """A state is terminal if it is won or there are no empty squares."""
        return state.utility != 0 or len(state.moves) == 0
    
    def custom_terminal_test(self, state):
        """A state is terminal if it is won or there are no empty squares."""
        return len(state.moves) == 0

    def display(self, state):
        board = state.board
        for x in range(1, self.h + 1):
            for y in range(1, self.v + 1):
                print(board.get((x, y), '.'), end=' ')
            print()
    
    def displayDyn(self, state):
        board = state.board
        res = ""
        for x in range(1, self.h + 1):
            for y in range(1, self.v + 1):
                res += str(board.get((x, y), '.'))+' '
            # res+="\n"
        return res

    def compute_utility(self, board, move, player):
        """If 'X' wins with this move, return 1; if 'O' wins return -1; else return 0."""
        if (self.k_in_row(board, move, player, (0, 1)) or
            self.k_in_row(board, move, player, (1, 0)) or
            self.k_in_row(board, move, player, (1, -1)) or
            self.k_in_row(board, move, player, (1, 1))):
            return +1 if player == 'X' else -1
        else:
            return 0

    def k_in_row(self, board, move, player, delta_x_y):
        """Return true if there is a line through move on board for player."""
        (delta_x, delta_y) = delta_x_y
        x, y = move
        n = 0  # n is number of moves in row
        # moving forward
        while board.get((x, y)) == player:
            n += 1
            x, y = x + delta_x, y + delta_y
        x, y = move
        # moving backward
        while board.get((x, y)) == player:
            n += 1
            x, y = x - delta_x, y - delta_y
        n -= 1  # Because we counted move itself twice
        return n >= self.k

    def custom_compute_utility(self, board, move, player):
        """If 'X' wins with this move, return 1; if 'O' wins return -1; else return 0."""
        a = self.custom_k_in_row(board, move, player, (0, 1))
        b = self.custom_k_in_row(board, move, player, (1, 0))
        c = self.custom_k_in_row(board, move, player, (1, -1))
        d = self.custom_k_in_row(board, move, player, (1, 1))
        e = max(a,b,c,d)
        if player == 'O':
            # also try to minimise X link count
            # make the same move for user and try to
            # minimize users chance to create any nearest link
            tempBoard = board
            tempBoard[move]='X'
            a = self.custom_k_in_row(tempBoard, move, 'X', (0, 1))
            b = self.custom_k_in_row(tempBoard, move, 'X', (1, 0))
            c = self.custom_k_in_row(tempBoard, move, 'X', (1, -1))
            d = self.custom_k_in_row(tempBoard, move, 'X', (1, 1))
            f = max(a,b,c,d)
            e = max(e,f)
            
        return +1*e if player == 'X' else -1*e

    def custom_k_in_row(self, board, move, player, delta_x_y):
        """Return true if there is a line through move on board for player."""
        (delta_x, delta_y) = delta_x_y
        x, y = move
        n = 0  # n is number of moves in row
        # moving forward
        while board.get((x, y)) == player:
            n += 1
            x, y = x + delta_x, y + delta_y
        x, y = move
        # moving backward
        while board.get((x, y)) == player:
            n += 1
            x, y = x - delta_x, y - delta_y
        n -= 1  # Because we counted move itself twice
        return n

# %% [markdown]
# ## Adversarial Search

# %% [markdown]
# ### Min Max Search Algorithm
# ---------------
# The minimax algorithm computes the minimax decision from the current state. It uses a simple recursive computation of the minimax values of each successor state, directly implementing the defining equations. The recursion proceeds all the way down to the leaves of the tree, and then the minimax values are backed up through the tree as the recursion unwinds.

# %%
def minmax_decision(state, game, *args):
    player = game.to_move(state)

    def max_value(state):
        if game.terminal_test(state):
            return game.utility(state, player)
        v = -np.inf
        for a in game.actions(state):
            v = max(v, min_value(game.result(state, a)))
        return v

    def min_value(state):
        if game.terminal_test(state):
            return game.utility(state, player)
        v = np.inf
        for a in game.actions(state):
            v = min(v, max_value(game.result(state, a)))
        return v
    
    # Body of minmax_decision:
    return max(game.actions(state), key=lambda a: min_value(game.result(state, a)))

# %% [markdown]
# ### Min Max Algorithm with Alpha Beta Pronning
# ----------------
# The problem with minimax search is that the number of game states it has to examine is exponential in the depth of the tree. Unfortunately, we can’t eliminate the exponent, but it turns out we can effectively cut it in half. The trick is that it is possible to compute the correct minimax decision without looking at every node in the game tree. That is, we can borrow the idea of pruning to eliminate large parts of the tree from consideration. The particular technique that is implimented is called alpha–beta pruning. When applied to a standard minimax tree, it returns the same move as minimax would, but prunes away branches that cannot possibly influence the final decision

# %%
def alpha_beta_search(state, game, *args):
    player = game.to_move(state)

    # Functions used by alpha_beta
    def max_value(state, alpha, beta):
        if game.terminal_test(state):
            return game.utility(state, player)
        v = -np.inf
        for a in game.actions(state):
            v = max(v, min_value(game.result(state, a), alpha, beta))
            if v >= beta:
                return v
            alpha = max(alpha, v)
        return v

    def min_value(state, alpha, beta):
        if game.terminal_test(state):
            return game.utility(state, player)
        v = np.inf
        for a in game.actions(state):
            v = min(v, max_value(game.result(state, a), alpha, beta))
            if v <= alpha:
                return v
            beta = min(beta, v)
        return v

    # Body of alpha_beta_search:
    best_score = -np.inf
    beta = np.inf
    best_action = None
    for a in game.actions(state):
        v = min_value(game.result(state, a), best_score, beta)
        if v > best_score:
            best_score = v
            best_action = a
    return best_action

# %% [markdown]
# ### Depth Limited Min Max Algorithm
# ------------------------
# The below is implimentation of Min Max Algorithm, but insted of just stopping at leaf node, if the tree traverses to a certail depth, the expansion stops and the values are calculated

# %%
def depth_limited_minmax_decision(state, game, maxDepth=5):
    player = game.to_move(state)
        
    startDepth = state.depth
    
    searchTree = dict() # parent: child
    maxDep = -1 # head node is at depth 0
    
    searchTree[game.displayDyn(state)] = dict()

    def max_value(state):
        if (game.terminal_test(state) or ( state.depth-startDepth > maxDepth ) ):
            # print(state.depth, startDepth)
            return game.utility(state, player)
        v = -np.inf
        for a in game.actions(state):
            v = max(v, min_value(game.result(state, a)))
        return v

    def min_value(state):
        if (game.terminal_test(state) or ( state.depth-startDepth > maxDepth ) ):
            # print(state.depth, startDepth)
            return game.utility(state, player)
        v = np.inf
        for a in game.actions(state):
            v = min(v, max_value(game.result(state, a)))
        return v
    
    allMoves = game.actions(state)
    result = max(allMoves, key=lambda a: min_value(game.result(state, a)))
    return result

# %% [markdown]
# ### Depth Limited Min Max Algorithm with Alpha Beta Prunning
# ------------------------
# The below is implimentation of Min Max Algorithm with Alpha Beta Prunning, but insted of just stopping at leaf node, if the tree traverses to a certail depth, the expansion stops and the values are calculated

# %%
def depth_limited_alpha_beta_search(state, game, maxDepth=5):
    player = game.to_move(state)
    
    startDepth = state.depth

    # Functions used by alpha_beta
    def max_value(state, alpha, beta):
        if ( game.terminal_test(state) or ( state.depth-startDepth > maxDepth) ):
            return game.utility(state, player)
        v = -np.inf
        for a in game.actions(state):
            v = max(v, min_value(game.result(state, a), alpha, beta))
            if v >= beta:
                return v
            alpha = max(alpha, v)
        return v

    def min_value(state, alpha, beta):
        if ( game.terminal_test(state) or ( state.depth-startDepth > maxDepth) ):
            return game.utility(state, player)
        v = np.inf
        for a in game.actions(state):
            v = min(v, max_value(game.result(state, a), alpha, beta))
            if v <= alpha:
                return v
            beta = min(beta, v)
        return v

    # Body of alpha_beta_search:
    best_score = -np.inf
    beta = np.inf
    best_action = None
    for a in game.actions(state):
        v = min_value(game.result(state, a), best_score, beta)
        if v > best_score:
            best_score = v
            best_action = a
    return best_action

# %% [markdown]
# ### Expermental Adversarial Search Algorithm
# -----------------------
# Implimentation of Min Max Algorithm with a better utility function with more emphasys on not letting user not complelet a set.

# %%
def custom_decision(state, game, maxDepth=1):
    player = game.to_move(state)
        
    startDepth = state.depth
    
    searchTree = dict() # parent: child
    maxDep = -1 # head node is at depth 0
    
    searchTree[game.displayDyn(state)] = dict()

    def max_value(state):
        if (game.custom_terminal_test(state) or ( state.depth-startDepth > maxDepth ) ):
            # print(state.depth, startDepth)
            return game.utility(state, player)
        v = -np.inf
        for a in game.actions(state):
            v = max(v, min_value(game.custom_result(state, a)))
        return v

    def min_value(state):
        if (game.custom_terminal_test(state) or ( state.depth-startDepth > maxDepth ) ):
            # print(state.depth, startDepth)
            return game.utility(state, player)
        v = np.inf
        for a in game.actions(state):
            v = min(v, max_value(game.custom_result(state, a)))
        return v
    
    allMoves = game.actions(state)
    result = max(allMoves, key=lambda a: min_value(game.custom_result(state, a)))
    return result

# %% [markdown]
# ## Play Time

# %% [markdown]
# ### Read Command Line input From user

# %%
def readUserInput(board, x_r=3, y_r=3):
    try:
        (x, y) = tuple(map(int, str(input()).split()))
        while ( x>x_r or x<1 or y>y_r or y<1 or (x,y) in board.keys() ):
            print("invalid input please try again")
            (x, y) = tuple(map(int, str(input()).split()))
        return (x, y)
    except:
        print("invalid input format, try again")

# %% [markdown]
# ### Command Line version to Play the Tic Tac Toe game

# %%
def playGame(decision_algo=depth_limited_minmax_decision , x_r=3, y_r=3, cutCount=3, maxDepth=3):
    sampStart = TicTacToe(x_r, y_r, cutCount)

    ittr = x_r*y_r # total Number of moves possible
    while(ittr>0):
        if (ittr!=0):
            print('User (X)')
            ittr-=1
            # User move
            NewUserMove = readUserInput(sampStart.initial.board, x_r, y_r)
            NewUserState = sampStart.result(sampStart.initial, NewUserMove)
            moveBy = sampStart.initial.to_move
            
            sampStart.display(NewUserState)
            print("state depth : ",NewUserState.depth)
            sampStart.initial = NewUserState
            decision = sampStart.compute_utility(
                sampStart.initial.board,
                NewUserMove,
                moveBy
            )
            if ( decision ):
                print(decision,'user wins')
                break
            print()

        if (ittr!=0):
            start = time.time()
            print("computer (0)")
            ittr-=1
            # Computer move
            NewMove = decision_algo(sampStart.initial, sampStart, maxDepth)
            NewState = sampStart.result(sampStart.initial, NewMove)
            moveBy = sampStart.initial.to_move
            print("time to compute : ",time.time()-start)
            sampStart.display(NewState)
            print("state depth : ",NewState.depth)
            sampStart.initial = NewState
            decision = sampStart.compute_utility(
                sampStart.initial.board,
                NewMove,
                moveBy
            )
            if ( decision ):
                print(decision,'computer wins')
                break
            print()

    if (ittr==0):
        print("Draw match. Nice play")
    print("-----------------------------")

# playGame(minmax_decision)

# %% [markdown]
# ### Visual version to play with Tic Tac Toe game using pygame

# %%
def playVis(x_l=3, y_l=3, cutCount=3,decision_algo=alpha_beta_search, maxDepth=3):
    # x_l row count, y_l column count
    
    sampStart = TicTacToe(y_l, x_l, cutCount)
    
    BLACK = (0, 0, 0)
    WHITE = (255, 255, 255)
    GREEN = (0, 255, 0)
    RED = (255, 0, 0)
    
    gridColor = [GREEN, RED]
    colorInd = 1
    
    # This sets the WIDTH and HEIGHT of each grid location
    WIDTH = 40
    HEIGHT = 40
    
    # to end process when there is not more move left
    moveCount = 0
    totalCount = x_l*y_l
    
    # This sets the margin between each cell
    MARGIN = 5

    # Create a 2 dimensional array. A two dimensional
    # array is simply a list of lists.
    grid = [[-1 for x in range(x_l)] for y in range(y_l)]

    # grid[i][j]=0 for green grid[i][j]=1 for red else -1         

    # Initialize pygame
    pygame.init()

    # Set the HEIGHT and WIDTH of the screen
    WINDOW_SIZE = [ (WIDTH+MARGIN)*x_l + 5 , (HEIGHT+MARGIN)*y_l + 5]
    screen = pygame.display.set_mode(WINDOW_SIZE)

    # Set title of screen
    pygame.display.set_caption("Tic Tac Toe")

    # Loop until the user clicks the close button.
    done = False

    # Used to manage how fast the screen updates
    clock = pygame.time.Clock()
    
    # playerTurn = 0  # user, 1 for computer
    
    playerTurn=1
    colorInd=1
    
    # Set the screen background
    screen.fill(BLACK)
    
    for row in range(y_l):
        for column in range(x_l):
            color = WHITE
            if grid[row][column] != -1:
                color = gridColor[ grid[row][column] ]
            pygame.draw.rect(
                screen,
                color,
                [
                    (MARGIN + WIDTH) * column + MARGIN,
                    (MARGIN + HEIGHT) * row + MARGIN,
                    WIDTH, HEIGHT
                ]
            )
    pygame.display.update()
    
    while not done:      
        invMove = False
        if (moveCount >= totalCount):
            print(decision,'Tie')
            pygame.display.set_caption("Draw match")
            time.sleep(2)
            done = True
            break
            
        for event in pygame.event.get():  # User did something
            pygame.display.set_caption("User Turn")
            if event.type == pygame.QUIT:  # If user clicked close
                done = True
            elif event.type == pygame.MOUSEBUTTONDOWN:
                invMove = False

                ## user move                
                # User clicks the mouse. Get the position
                pos = pygame.mouse.get_pos()

                # Change the x/y screen coordinates to grid coordinates
                column = pos[0] // (WIDTH + MARGIN)
                row = pos[1] // (HEIGHT + MARGIN)
                if ( (row+1, column+1) in sampStart.initial.board.keys() ):
                    pygame.display.set_caption("Invalid move")
                    print("invalid move found")
                    invMove = True

                else:
                    # -------------- User --------------------

                    colorInd = (colorInd+1)%2
                    playerTurn = (playerTurn+1)%2
                    
                    moveCount += 1
                    NewUserMove = ( row+1, column+1 )
                    NewUserState = sampStart.result(sampStart.initial, NewUserMove)
                    moveBy = sampStart.initial.to_move      
                    sampStart.display(NewUserState)
                    sampStart.initial = NewUserState
                    decision = sampStart.compute_utility(
                        sampStart.initial.board,
                        NewUserMove,
                        moveBy
                    )
                    
                    # Set that location to one
                    grid[row][column] = colorInd
                    print("Click ", pos, "Grid coordinates: ", row, column)
                    for row in range(y_l):
                        for column in range(x_l):
                            color = WHITE
                            if grid[row][column] != -1:
                                color = gridColor[ grid[row][column] ]
                            pygame.draw.rect(
                                screen,
                                color,
                                [
                                    (MARGIN + WIDTH) * column + MARGIN,
                                    (MARGIN + HEIGHT) * row + MARGIN,
                                    WIDTH, HEIGHT
                                ]
                            )
                    pygame.display.update()

                    if ( decision ):
                        print(decision,'user wins')
                        pygame.display.set_caption("User Win")
                        time.sleep(2)
                        done = True
                        break
                    print()
                    
                    # --------- Chenk for no more moves left ---------
                    if (moveCount >= totalCount):
                        print(decision,'Tie')
                        pygame.display.set_caption("Draw match")
                        time.sleep(2)
                        done = True
                        break
                    
                    # ----------- Computer -------------------
                    pygame.display.set_caption("Computer Calculating")
                    
                    colorInd = (colorInd+1)%2
                    playerTurn = (playerTurn+1)%2
                    
                    ## computer starts calculating its move
                    moveCount += 1
                    # get from agent
                    print("comuter loading")
                    NewMove = decision_algo(sampStart.initial, sampStart, maxDepth)
                    print("results found")
                    row = NewMove[0]-1
                    column = NewMove[1]-1
                    if ( (row+1, column+1) in sampStart.initial.board.keys() ):
                        pygame.display.set_caption("Invalid move")
                        print("invalid move found")
                        invMove = True

                    pos = (row, column)
                    NewState = sampStart.result(sampStart.initial, NewMove)
                    moveBy = sampStart.initial.to_move
                    sampStart.display(NewState)
                    sampStart.initial = NewState
                    decision = sampStart.compute_utility(
                        sampStart.initial.board,
                        NewMove,
                        moveBy
                    )
                    
                    # Set that location to one
                    grid[row][column] = colorInd
                    print("Click ", pos, "Grid coordinates: ", row, column)
                    for row in range(y_l):
                        for column in range(x_l):
                            color = WHITE
                            if grid[row][column] != -1:
                                color = gridColor[ grid[row][column] ]
                            pygame.draw.rect(
                                screen,
                                color,
                                [
                                    (MARGIN + WIDTH) * column + MARGIN,
                                    (MARGIN + HEIGHT) * row + MARGIN,
                                    WIDTH, HEIGHT
                                ]
                            )
                    pygame.display.update()
                    
                    if ( decision ):
                        print(decision,'computer wins')
                        pygame.display.set_caption("Computer Win")
                        time.sleep(2)
                        done = True
                    print()
    pygame.quit()

# %% [markdown]
# ### Taking input for playing the game

# %%
def takePref():
    row = int(input("Enter Number of Row's(3) : "))
    column = int(input("Enter Number of Columns's(3) : "))
    cutCount = int(input("Enter Cut Count(3) : "))
    print('Choose the algorithm of your choice : ')
    print('1. Min Max')
    print("2. Min Max with Alpha Beta Prunning")
    print("3. Depth Limited Min Max")
    print("4. Depth Limited Min Max with Alpha Beta Prunning")
    print("5. custom_decision")
    algoChoice = str(input("Make Your Choice : "))
    choiceDepth = 3
    if int(algoChoice) >= 3 :
        choiceDepth = int(input("Enter max search depth : "))
    algoCount = {
        "1" : minmax_decision,
        "2" : alpha_beta_search,
        "3" : depth_limited_minmax_decision,
        "4" : depth_limited_alpha_beta_search,
        "5" : custom_decision
    }
    playVis(row, column, cutCount, algoCount[algoChoice], choiceDepth)
takePref()

# %%
# If there is some error while running the pygame and the kernel frooze,
# please uncomment the below line and run this part. (just in case, although that won't happen)
# pygame.quit()
